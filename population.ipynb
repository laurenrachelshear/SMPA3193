# %%
import agate
counties = agate.Table.from_csv("county_population.csv")
print counties
popchange1016 = counties.compute([('change', agate.PercentChange('estimate_2010', 'estimate_2015'))
])
print popchange1016[0]['change']
from decimal import Decimal
def round_change(row):return row['change'].quantize(Decimal('0.1'))
rounded_change = popchange1016.compute([('change_rounded', agate.Formula(agate.Number(), round_change))])
print rounded_change[0]['change_rounded']
sorted_counties = rounded_change.order_by('change', reverse=True)
sorted_counties.select(['county', 'state', 'change_rounded']).print_table(max_rows=50)
import re
by_northdakota = sorted_counties.where(lambda row: 'North Dakota' in row['state'])
by_northdakota.select(['county', 'change_rounded']).print_table()
sorted_counties = rounded_change.order_by('change')
sorted_counties.select(['county', 'state', 'change_rounded']).print_table(max_rows=50)
import agate
counties = agate.Table.from_csv("county_population.csv")
print counties
by_estimate_2015 = counties.group_by('county')
by_estimate_2015 = counties.order_by('estimate_2015', reverse=True)
by_estimate_2015.select(['county']).print_table()
import agate
counties = agate.Table.from_csv("county_population.csv")
print counties
popchange1016 = counties.compute([('change', agate.PercentChange('estimate_2010', 'estimate_2015'))
])
print popchange1016[0]['change']
from decimal import Decimal
def round_change(row):return row['change'].quantize(Decimal('0.1'))
rounded_change = popchange1016.compute([('change_rounded', agate.Formula(agate.Number(), round_change))])
print rounded_change[0]['change_rounded']
by_state = rounded_change.group_by('state')
change_rounded_avg = by_state.aggregate([('ave_change_rounded', agate.Mean('change_rounded'))])
change_rounded_avg.order_by('state' , reverse =True) .print_table ( )
# Out:
# | column        | data_type |
# | ------------- | --------- |
# | county        | Text      |
# | state         | Text      |
# | estimate_2010 | Number    |
# | estimate_2011 | Number    |
# | estimate_2012 | Number    |
# | estimate_2013 | Number    |
# | estimate_2014 | Number    |
# | estimate_2015 | Number    |
#
# 1.256860592755214050493962678
# 1.3
# | county              | state          | change_rounded |
# | ------------------- | -------------- | -------------- |
# | McKenzie County     | North Dakota   |          100.4 |
# | Williams County     | North Dakota   |           56.3 |
# | Loving County       | Texas          |           34.9 |
# | Mountrail County    | North Dakota   |           33.8 |
# | Stark County        | North Dakota   |           32.0 |
# | Dunn County         | North Dakota   |           31.2 |
# | Sumter County       | Florida        |           26.1 |
# | Wasatch County      | Utah           |           23.4 |
# | St. Bernard Parish  | Louisiana      |           23.4 |
# | Hays County         | Texas          |           23.0 |
# | Richland County     | Montana        |           22.7 |
# | Andrews County      | Texas          |           22.0 |
# | Billings County     | North Dakota   |           21.4 |
# | Fort Bend County    | Texas          |           21.3 |
# | Long County         | Georgia        |           20.7 |
# | Forsyth County      | Georgia        |           20.2 |
# | Dallas County       | Iowa           |           20.1 |
# | Osceola County      | Florida        |           20.1 |
# | Kendall County      | Texas          |           20.0 |
# | Williamson County   | Texas          |           19.2 |
# | Loudoun County      | Virginia       |           19.0 |
# | Sterling County     | Texas          |           18.8 |
# | St. Johns County    | Florida        |           18.5 |
# | Comal County        | Texas          |           18.1 |
# | Divide County       | North Dakota   |           17.9 |
# | Burke County        | North Dakota   |           17.8 |
# | Midland County      | Texas          |           17.6 |
# | Martin County       | Texas          |           17.1 |
# | Denton County       | Texas          |           17.0 |
# | Montgomery County   | Texas          |           17.0 |
# | Lincoln County      | South Dakota   |           17.0 |
# | Uintah County       | Utah           |           16.9 |
# | Ector County        | Texas          |           16.3 |
# | Fredericksburg city | Virginia       |           16.2 |
# | Morgan County       | Utah           |           16.1 |
# | Collin County       | Texas          |           15.9 |
# | Broomfield County   | Colorado       |           15.6 |
# | Bryan County        | Georgia        |           15.6 |
# | Columbia County     | Georgia        |           15.3 |
# | Crane County        | Texas          |           15.3 |
# | McMullen County     | Texas          |           15.2 |
# | Rockwall County     | Texas          |           15.1 |
# | Williamson County   | Tennessee      |           15.0 |
# | Walton County       | Florida        |           15.0 |
# | Ward County         | North Dakota   |           14.8 |
# | Canadian County     | Oklahoma       |           14.6 |
# | Horry County        | South Carolina |           14.3 |
# | Greenlee County     | Arizona        |           14.3 |
# | Travis County       | Texas          |           14.2 |
# | Cass County         | North Dakota   |           14.1 |
# | ...                 | ...            |            ... |
# | county               | change_rounded |
# | -------------------- | -------------- |
# | McKenzie County      |          100.4 |
# | Williams County      |           56.3 |
# | Mountrail County     |           33.8 |
# | Stark County         |           32.0 |
# | Dunn County          |           31.2 |
# | Billings County      |           21.4 |
# | Divide County        |           17.9 |
# | Burke County         |           17.8 |
# | Ward County          |           14.8 |
# | Cass County          |           14.1 |
# | Burleigh County      |           13.8 |
# | McHenry County       |           10.6 |
# | Morton County        |            9.9 |
# | Golden Valley County |            9.6 |
# | Hettinger County     |            9.3 |
# | McLean County        |            8.4 |
# | Grand Forks County   |            5.9 |
# | Sioux County         |            5.3 |
# | Slope County         |            5.2 |
# | Mercer County        |            5.1 |
# | ...                  |            ... |
# | county              | state          | change_rounded |
# | ------------------- | -------------- | -------------- |
# | Alexander County    | Illinois       |          -17.5 |
# | Terrell County      | Texas          |          -17.0 |
# | Butte County        | Idaho          |          -14.0 |
# | Presidio County     | Texas          |          -12.7 |
# | Lee County          | Kentucky       |          -12.4 |
# | McPherson County    | Nebraska       |          -11.5 |
# | Macon County        | Alabama        |          -11.3 |
# | Bristol Bay Borough | Alaska         |          -11.0 |
# | Ontonagon County    | Michigan       |          -10.9 |
# | Bent County         | Colorado       |          -10.4 |
# | Dundy County        | Nebraska       |          -10.4 |
# | McDowell County     | West Virginia  |          -10.1 |
# | Clark County        | Idaho          |          -10.1 |
# | Lassen County       | California     |          -10.0 |
# | Phillips County     | Arkansas       |           -9.9 |
# | Cimarron County     | Oklahoma       |           -9.8 |
# | Dickens County      | Texas          |           -9.8 |
# | Colfax County       | New Mexico     |           -9.6 |
# | De Baca County      | New Mexico     |           -9.4 |
# | Elk County          | Kansas         |           -9.3 |
# | Tensas Parish       | Louisiana      |           -9.3 |
# | Hancock County      | Georgia        |           -9.2 |
# | Wheeler County      | Nebraska       |           -9.0 |
# | Monroe County       | Arkansas       |           -8.9 |
# | Hidalgo County      | New Mexico     |           -8.9 |
# | Foard County        | Texas          |           -8.8 |
# | Allendale County    | South Carolina |           -8.8 |
# | Coosa County        | Alabama        |           -8.8 |
# | San Juan County     | New Mexico     |           -8.8 |
# | Las Animas County   | Colorado       |           -8.7 |
# | Rock County         | Nebraska       |           -8.7 |
# | Holt County         | Missouri       |           -8.6 |
# | Hamilton County     | Kansas         |           -8.5 |
# | Fulton County       | Kentucky       |           -8.4 |
# | Perry County        | Alabama        |           -8.4 |
# | Lafayette County    | Arkansas       |           -8.4 |
# | Quitman County      | Mississippi    |           -8.3 |
# | Hinsdale County     | Colorado       |           -8.3 |
# | Schleicher County   | Texas          |           -8.3 |
# | Turner County       | Georgia        |           -8.2 |
# | Quitman County      | Georgia        |           -8.2 |
# | Jones County        | South Dakota   |           -8.1 |
# | Jeff Davis County   | Texas          |           -8.1 |
# | Sierra County       | California     |           -7.9 |
# | Floyd County        | Texas          |           -7.9 |
# | Stanton County      | Kansas         |           -7.8 |
# | Garden County       | Nebraska       |           -7.8 |
# | Tyrrell County      | North Carolina |           -7.8 |
# | Briscoe County      | Texas          |           -7.7 |
# | Desha County        | Arkansas       |           -7.7 |
# | ...                 | ...            |            ... |
# | column        | data_type |
# | ------------- | --------- |
# | county        | Text      |
# | state         | Text      |
# | estimate_2010 | Number    |
# | estimate_2011 | Number    |
# | estimate_2012 | Number    |
# | estimate_2013 | Number    |
# | estimate_2014 | Number    |
# | estimate_2015 | Number    |
#
# | county               |
# | -------------------- |
# | Los Angeles County   |
# | Cook County          |
# | Harris County        |
# | Maricopa County      |
# | San Diego County     |
# | Orange County        |
# | Miami-Dade County    |
# | Kings County         |
# | Dallas County        |
# | Riverside County     |
# | Queens County        |
# | San Bernardino Co... |
# | King County          |
# | Clark County         |
# | Tarrant County       |
# | Santa Clara County   |
# | Bexar County         |
# | Broward County       |
# | Wayne County         |
# | New York County      |
# | ...                  |
# | column        | data_type |
# | ------------- | --------- |
# | county        | Text      |
# | state         | Text      |
# | estimate_2010 | Number    |
# | estimate_2011 | Number    |
# | estimate_2012 | Number    |
# | estimate_2013 | Number    |
# | estimate_2014 | Number    |
# | estimate_2015 | Number    |
#
# 1.256860592755214050493962678
# 1.3
# | state          | ave_change_rounded |
# | -------------- | ------------------ |
# | Wyoming        |             2.174… |
# | Wisconsin      |             0.026… |
# | West Virginia  |            -1.511… |
# | Washington     |             3.074… |
# | Virginia       |             1.370… |
# | Vermont        |            -0.564… |
# | Utah           |             4.945… |
# | Texas          |             2.587… |
# | Tennessee      |             1.281… |
# | South Dakota   |             1.295… |
# | South Carolina |             1.263… |
# | Rhode Island   |            -0.520… |
# | Pennsylvania   |            -0.718… |
# | Oregon         |             1.564… |
# | Oklahoma       |             1.030… |
# | Ohio           |            -0.498… |
# | North Dakota   |             7.789… |
# | North Carolina |             1.262… |
# | New York       |            -0.710… |
# | New Mexico     |            -2.121… |
# | ...            |                ... |
